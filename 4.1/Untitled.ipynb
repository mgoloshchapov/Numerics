# %%
import numpy as np
import pandas as pd

# %%
import io


path = "/Users/goloshch/Downloads/vidnost0sm.dat"

data = pd.read_fwf(path)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [13], in <module>
#       1 import io
#       4 path = "/Users/goloshch/Downloads/vidnost0sm.dat"
# ----> 6 data = pd.read_fwf(path)
#
# File ~/.conda/envs/NPM/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.conda/envs/NPM/lib/python3.10/site-packages/pandas/io/parsers/readers.py:876, in read_fwf(filepath_or_buffer, colspecs, widths, infer_nrows, **kwds)
#     874 kwds["infer_nrows"] = infer_nrows
#     875 kwds["engine"] = "python-fwf"
# ...
